# %% [markdown]
# # Here are some challenge problems
#
# Some of you might remember Zika Virus. It is a mosquito-borne virus that in uncommon cases can cause birth defect in pregnant women. It can also trigger Guillain-Barré Syndrome, a disorder where your own immune system attacks your nerves, in a few cases.
# We have some datasets from the CDC that you can work on. The files are already in the repo, but if you're interested, you can check out other data [here](https://github.com/BuzzFeedNews/zika-data).

# %% [markdown]
# ### Challenge One
#
# According to the CDC data from 12/28/2016, which three states or territories have the most travel acquired cases? Which state or territory has the most total cases?

# %%
### TODO

# %% [markdown]
# ### Challenge Two
#
# According to the CDC data from 1/10/2018, which states or territories have absolutely no symptomatic cases or presumptive viremic blood donors?

# %%
### TODO

# %% [markdown]
# ### Challenge Three
#
# According to Colombia's data from 02/13/2016, how many total cases are there in the country?

# %%
### TODO
